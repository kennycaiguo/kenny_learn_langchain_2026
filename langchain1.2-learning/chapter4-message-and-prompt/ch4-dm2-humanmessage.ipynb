# %% [markdown]
# ## 关于HumanMessage构造函数里面的元数据
# ### 先测试一下openai/gpt-oss-120b大模型

# %%
from langchain.chat_models import init_chat_model
from langchain_core.messages import HumanMessage,SystemMessage


llm = init_chat_model(
    model="openai/gpt-oss-120b",  # 指定具体的 Groq 模型名称
    model_provider="groq",    # 明确指定提供商为 groq
    temperature=0.7
)

# 调用模型
messages = [
  SystemMessage("""你是一个消息抽取器。你会收到来自不同发言者的user消息。每条消息可能带有name字段。
   你的任务是：严格根据每条消息的name提取发言者及其观点，并输出JSON。禁止使用”第一人称/第二人称“这种称呼。
   若某条消息没有name，则输出unknown。输出格式：{\"speakers\":[{\"name\":\"...\",\"claim\":\"}]}"""),
  HumanMessage(
       content="我认为日本的首都是大阪",
       name="Bob"
  ),
  HumanMessage(
      content="我认为日本的首都是东京",
      name="Mary"
  ),
  HumanMessage(
      content="请列出谁说了什么，不要判断对错",
      name="audience"
  )
]

response = llm.invoke(messages)

# 打印输出结果
response.pretty_print()
# Out:
# ================================== Ai Message ==================================
#
# {
#   "speakers": [
#     {
#       "name": "unknown",
#       "claim": "我认为日本的首都是大阪"
#     },
#     {
#       "name": "unknown",
#       "claim": "我认为日本的首都是东京"
#     },
#     {
#       "name": "unknown",
#       "claim": "请列出谁说了什么，不要判断对错"
#     }
#   ]
# }

# %% [markdown]
# ## 看看gemini-3.1-flash-lite是否支持name字段

# %%
from langchain_openai import ChatOpenAI
from dotenv import load_dotenv
from langchain_core.messages import HumanMessage,SystemMessage
import os

load_dotenv(override=True)
gemini_api_key = os.getenv("gemini_api_key")

llm = ChatOpenAI(
    model="gemini-3.1-flash-lite",
    api_key=gemini_api_key,
    base_url="https://generativelanguage.googleapis.com/v1beta/openai/"
)

messages = [
  SystemMessage("""你是一个消息抽取器。你会收到来自不同发言者的user消息。每条消息可能带有name字段。
   你的任务是：严格根据每条消息的name提取发言者及其观点，并输出JSON。禁止使用”第一人称/第二人称“这种称呼。
   若某条消息没有name，则输出unknown。输出格式：{\"speakers\":[{\"name\":\"...\",\"claim\":\"}]}"""),
  HumanMessage(
       content="我认为日本的首都是大阪",
       name="Bob"
  ),
  HumanMessage(
      content="我认为日本的首都是东京",
      name="Mary"
  ),
  HumanMessage(
      content="请列出谁说了什么，不要判断对错",
      name="audience"
  )
]

resp = llm.invoke(messages)
resp.pretty_print()
# Out:
# ================================== Ai Message ==================================
#
# ```json
# {
#   "speakers": [
#     {
#       "name": "unknown",
#       "claim": "日本的首都是大阪"
#     },
#     {
#       "name": "unknown",
#       "claim": "日本的首都是东京"
#     }
#   ]
# }
# ```

# %% [markdown]
# ## deepseek本地大模型

# %%
from langchain_ollama import ChatOllama
import rich

llm = ChatOllama(
    model='deepseek-r1:8b'
)

messages = [
  SystemMessage("""你是一个消息抽取器。你会收到来自不同发言者的user消息。每条消息可能带有name字段。
   你的任务是：严格根据每条消息的name提取发言者及其观点，并输出JSON。禁止使用”第一人称/第二人称“这种称呼。
   若某条消息没有name，则输出unknown。输出格式：{\"speakers\":[{\"name\":\"...\",\"claim\":\"}]}"""),
  HumanMessage(
       content="我认为日本的首都是大阪",
       name="Bob"
  ),
  HumanMessage(
      content="我认为日本的首都是东京",
      name="Mary"
  ),
  HumanMessage(
      content="请列出谁说了什么，不要判断对错",
      name="audience"
  )
]

resp = llm.invoke(messages)

rich.print(resp)
# Out:
# AIMessage(
#     content='\n{"speakers":[{"name":"unknown","claim":"我认为日本的首都是大阪"},{"name":"unknown","claim":"我认为日
# 本的首都是东京"}]}',
#     additional_kwargs={},
#     response_metadata={
#         'model': 'deepseek-r1:8b',
#         'created_at': '2026-09-10T00:34:41.1607857Z',
#         'done': True,
#         'done_reason': 'stop',
#         'total_duration': 992718079500,
#         'load_duration': 9486645000,
#         'prompt_eval_count': 115,
#         'prompt_eval_duration': 5705771000,
#         'eval_count': 3166,
#         'eval_duration': 977439312000,
#         'logprobs': None,
#         'model_name': 'deepseek-r1:8b',
#         'model_provider': 'ollama'
#     },
#     id='lc_run--01a088ad-d3b7-7a73-9904-190bc37b7bf8-0',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     usage_metadata={'input_tokens': 115, 'output_tokens': 3166, 'total_tokens': 3281}
# )

# %% [markdown]
# ## gemma本地大模型

# %%
from langchain_ollama import ChatOllama
import rich

llm = ChatOllama(
    model='gemma4:latest'
)

messages = [
  SystemMessage("""你是一个消息抽取器。你会收到来自不同发言者的user消息。每条消息可能带有name字段。
   你的任务是：严格根据每条消息的name提取发言者及其观点，并输出JSON。禁止使用”第一人称/第二人称“这种称呼。
   若某条消息没有name，则输出unknown。输出格式：{\"speakers\":[{\"name\":\"...\",\"claim\":\"}]}"""),
  HumanMessage(
       content="我认为日本的首都是大阪",
       name="Bob"
  ),
  HumanMessage(
      content="我认为日本的首都是东京",
      name="Mary"
  ),
  HumanMessage(
      content="请列出谁说了什么，不要判断对错",
      name="audience"
  )
]

resp = llm.invoke(messages)

rich.print(resp)
# Out:
# AIMessage(
#     content='```json\n{\n  "speakers": [\n    {\n      "name": "unknown",\n      "claim": "日本的首都是大阪"\n
# },\n    {\n      "name": "unknown",\n      "claim": "日本的首都是东京"\n    },\n    {\n      "name": "unknown",\n
# "claim": "请求列出发言者说了什么，并不要判断对错"\n    }\n  ]\n}\n```',
#     additional_kwargs={},
#     response_metadata={
#         'model': 'gemma4:latest',
#         'created_at': '2026-09-09T23:07:47.8475667Z',
#         'done': True,
#         'done_reason': 'stop',
#         'total_duration': 92328591000,
#         'load_duration': 10952219800,
#         'prompt_eval_count': 134,
#         'prompt_eval_duration': 3651744000,
#         'eval_count': 575,
#         'eval_duration': 77713165000,
#         'logprobs': None,
#         'model_name': 'gemma4:latest',
#         'model_provider': 'ollama'
#     },
#     id='lc_run--01a0886c-045c-7111-9619-7fba784297f8-0',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     usage_metadata={'input_tokens': 134, 'output_tokens': 575, 'total_tokens': 709}
# )

# %% [markdown]
# ## MoleAPI大模型

# %%
from langchain_openai import ChatOpenAI
from dotenv import load_dotenv
from langchain_core.messages import HumanMessage,SystemMessage
import os

load_dotenv(override=True)
MoleAPI_API_KEY = os.getenv("MoleAPI_API_KEY")
MoleAPI_BASE_URL = os.getenv("MoleAPI_BASE_URL")

llm = ChatOpenAI(
    model="gpt-4o-mini",
    api_key=MoleAPI_API_KEY,
    base_url=MoleAPI_BASE_URL
)

messages = [
  SystemMessage("""你是一个消息抽取器。你会收到来自不同发言者的user消息。每条消息可能带有name字段。
   你的任务是：严格根据每条消息的name提取发言者及其观点，并输出JSON。禁止使用”第一人称/第二人称“这种称呼。
   若某条消息没有name，则输出unknown。输出格式：{\"speakers\":[{\"name\":\"...\",\"claim\":\"}]}"""),
  HumanMessage(
       content="我认为日本的首都是大阪",
       name="Bob"
  ),
  HumanMessage(
      content="我认为日本的首都是东京",
      name="Mary"
  ),
  HumanMessage(
      content="请列出谁说了什么，不要判断对错",
      name="audience"
  )
]

resp = llm.invoke(messages)
resp.pretty_print()
# Out:
# ================================== Ai Message ==================================
#
# {"speakers":[{"name":"unknown","claim":"日本的首都是大阪"},{"name":"unknown","claim":"日本的首都是东京"}]}

# %% [markdown]
# ## AIMessage参数

# %%
from langchain_openai import ChatOpenAI
from dotenv import load_dotenv
from langchain_core.messages import HumanMessage,SystemMessage
import os

load_dotenv(override=True)
MoleAPI_API_KEY = os.getenv("MoleAPI_API_KEY")
MoleAPI_BASE_URL = os.getenv("MoleAPI_BASE_URL")

llm = ChatOpenAI(
    model="gpt-4o-mini",
    api_key=MoleAPI_API_KEY,
    base_url=MoleAPI_BASE_URL
)

messages = [
  SystemMessage("""你叫做夏敏，是一个助人为乐的人工智能助手"""),
  HumanMessage(
       content="请用简明扼要的词语介绍你自己",
       name="Bob"
  )
]

resp = llm.invoke(messages)
resp.pretty_print()
# Out:
# ================================== Ai Message ==================================
#
# 我是夏敏，一个助人为乐的人工智能助手，旨在提供信息、解答问题和支持用户。

# %%
import rich

rich.print(resp)
# Out:
# AIMessage(
#     content='我是夏敏，一个助人为乐的人工智能助手，旨在提供信息、解答问题和支持用户。',
#     additional_kwargs={'refusal': None},
#     response_metadata={
#         'token_usage': {
#             'completion_tokens': 25,
#             'prompt_tokens': 38,
#             'total_tokens': 63,
#             'completion_tokens_details': None,
#             'prompt_tokens_details': None
#         },
#         'model_provider': 'openai',
#         'model_name': 'gpt-4o-mini',
#         'system_fingerprint': None,
#         'id': 'resp_007597df8d40a481016aa21600d86487d0b3607683101d16f4',
#         'service_tier': 'default',
#         'finish_reason': 'stop',
#         'logprobs': None
#     },
#     id='lc_run--01a08925-dff1-7e80-b7b1-ea8f3e6a786b-0',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     usage_metadata={
#         'input_tokens': 38,
#         'output_tokens': 25,
#         'total_tokens': 63,
#         'input_token_details': {},
#         'output_token_details': {}
#     }
# )
