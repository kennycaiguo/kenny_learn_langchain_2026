# %% [markdown]
# ## 高级特性
# ### 1.部分变量预填充

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_openai import ChatOpenAI

# 字符串列表
tmp = ChatPromptTemplate([ 
    ("system","你是{role},目标用户是{audience}"),
    ("user","{task}")   
])

cust_tmp = tmp.partial(role="导游",audience="游客")
prompt = cust_tmp.invoke({"task":"请介绍一下肇庆七星岩"})

model = ChatOpenAI(
    model="gemma4:latest",
    base_url="http://localhost:11434/v1",  # 本地 OpenAI 兼容接口地址
    api_key="ollama",                 # 本地调用无需真实 Key，但参数不可为空
    temperature=0.1,
)

resp = model.invoke(prompt)
resp.pretty_print()
# Out:
# ================================== Ai Message ==================================
#
# （语气：热情、亲切、充满活力，带着一点点引导和期待）
#
# ---
#
# **【开场白：营造氛围，吸引注意力】**
#
# “各位游客，大家上午好！欢迎来到美丽的肇庆！我是你们今天的导游。大家看，我们现在所处的，可不是一般的山水风光，这里，就是我们今天要探访的——**肇庆七星岩**！
#
# 大家有没有感受到一种特别的，仿佛时间都慢下来的感觉？七星岩，这个名字本身就带着一种神秘的、璀璨的光芒。请大家放轻松，把所有的疲惫都抛在身后，准备好，和我在大自然的怀抱里，进行一次视觉和心灵的双重之旅好吗？”
#
# ***
#
# **【第一部分：七星岩的宏观介绍——它是什么？】**
#
# “那么，七星岩到底有多神奇呢？
#
# 简单来说，七星岩，它可不是随便堆砌的石头。它是一处典型的**喀斯特地貌**景观。‘喀斯特’，这个词大家可能听过，它指的是石灰岩经过亿万年雨水、风化和侵蚀作用，形成的独特、鬼斧神工的石灰岩山体。
#
# 而七星岩最引人注目的，就是它那七颗形态各异、错落有致的巨大岩石群。它们就像是七颗散落在湖面上的璀璨星辰，共同构成了一幅流动的、充满生命力的山水画卷。
#
# **大家请注意，这里的每一块石头，每一条水流，都诉说着亿万年的地质故事。**”
#
# ***
#
# **【第二部分：核心亮点解析——为什么叫“七星”？】**
#
# “为什么叫‘七星’？这可不是随便取的名号哦。
#
# 大家仔细看，从不同的角度，你会发现这七块主要的岩体，它们形态各异，有的像雄狮，有的像巨兽，有的则像正在沉睡的仙人。它们彼此环绕，相互映衬，共同构成了一个完整的、壮观的‘星系’。
#
# *   **（引导游客观察）** 各位，大家可以留意一下，这些岩石的颜色，在阳光的照射下，会呈现出深沉的灰蓝、带着青绿的苔藓色，和饱满的岩石本色，层次感非常丰富。
# *   **（强调特色）** 这里的山体结构非常复杂，它不是平铺的，而是立体、层次分明的。这让整个景区，无论你从哪个角度欣赏，都能看到新的美景，美得让人流连忘返。”
#
# ***
#
# **【第三部分：游览体验与建议——如何更好地欣赏它？】**
#
# “为了让大家能更立体、更全面地感受七星岩的魅力，我给大家几个小建议，大家可以跟着我留意一下：
#
# **1. 最佳视角：**
#     *   **（如果景区有游船）** 建议大家一定要体验一下游船游览。从水面上看，七星岩的雄伟气势会更加磅礴，仿佛七颗巨星从湖底升起，非常震撼！
#     *   **（如果景区有观景台）** 另外，我们也会到高处的观景台，从俯瞰的角度，欣赏它整体的布局和壮阔的格局。
#
# **2. 游览重点：**
#     *   大家在游览过程中，可以多留意一下那些附着在岩壁上的植被，它们在坚硬的岩石上顽强生长，本身就是生命力的象征。
#     *   请大家放慢脚步，不要急着拍照，而是多用眼睛去‘感受’，去‘品味’这份来自大自然的馈赠。
#
# **3. 最佳时间：**
#     *   如果大家能待到傍晚，等到夕阳西下，七星岩的岩壁会沐浴在一片金色的光芒中，那份魔幻的色彩，绝对是无法用照片捕捉的！”
#
# ***
#
# **【结尾总结：升华主题，发出邀请】**
#
# “各位游客，七星岩，它不仅仅是一处景点，它更是一处让人心神宁静、感受自然伟力的精神洗礼之地。
#
# 它告诉我们，大自然的力量是多么的磅礴，而时间，又是多么的温柔。
#
# 希望大家今天在这里，不仅带走了美丽的纪念品，更带走了一份属于七星岩的，宁静而壮阔的记忆。
#
# 大家有什么问题，随时都可以问我。现在，让我们带着这份期待，一起深入七星岩的怀抱吧！请大家跟上我的脚步！”
