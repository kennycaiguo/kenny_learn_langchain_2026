# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 1.字符串列表

# %%
from click import format_filename
from langchain_core.prompts import ChatPromptTemplate
from langchain_openai import ChatOpenAI

# 字符串列表
tmp = ChatPromptTemplate([ 
    "你好，我是{name}"    
])

prompt = tmp.format(name="Kenny")

model = ChatOpenAI(
    model="gemma4:latest",
    base_url="http://localhost:11434/v1",  # 本地 OpenAI 兼容接口地址
    api_key="ollama",                 # 本地调用无需真实 Key，但参数不可为空
    temperature=0.1,
)

resp = model.invoke(prompt)
resp.pretty_print()
# Out:
# ================================== Ai Message ==================================
#
# 你好，Kenny！很高兴认识你。😊
#
# (Hello, Kenny! Nice to meet you.)

# %% [markdown]
# ## 2.元组列表

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_openai import ChatOpenAI

# 字符串列表
tmp = ChatPromptTemplate([ 
    ("user","{user_input}")   
])

prompt = tmp.format(user_input="世界7大奇迹是什么")

model = ChatOpenAI(
    model="gemma4:latest",
    base_url="http://localhost:11434/v1",  # 本地 OpenAI 兼容接口地址
    api_key="ollama",                 # 本地调用无需真实 Key，但参数不可为空
    temperature=0.1,
)

resp = model.invoke(prompt)
resp.pretty_print()
# Out:
# ================================== Ai Message ==================================
#
# “世界七大奇迹”这个说法，在不同的历史时期和语境下，指代的是两套不同的奇迹：**古代七大奇迹**和**新世界七大奇迹**。
#
# 为了给您一个完整的答案，我将分别介绍这两套列表。
#
# ---
#
# ### 🏛️ 一、 古代七大奇迹 (The Seven Wonders of the Ancient World)
#
# 这是历史上最著名、最原始的“七大奇迹”列表。这些奇迹大多已经不复存在，只留下了考古遗迹。
#
# **古代七大奇迹包括：**
#
# 1. **吉萨金字塔 (Great Pyramid of Giza)：** 位于埃及，是古代奇迹中唯一至今保存完好的建筑。
# 2. **巴比伦空中花园 (Hanging Gardens of Babylon)：** 位于今伊拉克，传说由尼布甲尼茨王建造，以其壮观的园林景观闻名。
# 3. **奥林匹亚宙斯神像 (Statue of Zeus at Olympia)：** 位于希腊，由菲狄亚斯雕刻的巨型宙斯雕像。
# 4. **阿耳忒弥斯神庙 (Temple of Artemis at Ephesus)：** 位于今土耳其，一座宏伟的神庙。
# 5. **哈利卡纳索斯陵墓 (Mausoleum at Halicarnassus)：** 位于今土耳其，为一位君主建造的宏伟陵墓。
# 6. **罗德岛巨像 (Colossus of Rhodes)：** 位于希腊罗德岛，一座巨大的宙斯神像雕塑。
# 7. **亚历山大灯塔 (Lighthouse of Alexandria)：** 位于埃及亚历山大港，古代最宏伟的灯塔。
#
# ---
#
# ### 🌎 二、 新世界七大奇迹 (The New Seven Wonders of the World)
#
# 由于古代奇迹大多已失传，国际上于2007年发起了一项运动，重新选出了现代的“新世界七大奇迹”。这个列表是目前最常被提及的“世界七大奇迹”。
#
# **新世界七大奇迹包括：**
#
# 1. **中国长城 (Great Wall of China)：** 位于中国，人类历史上最宏伟的防御工程。
# 2. **马丘比丘 (Machu Picchu)：** 位于秘鲁，一座保存完好的印加文明古城。
# 3. **奇琴伊察 (Chichen Itza)：** 位于墨西哥，一座重要的玛雅文明遗址。
# 4. **科罗纳多大教堂 (The Alhambra)：** 位于西班牙格拉纳达，一座典型的摩尔式宫殿建筑群。
# 5. **基督救世主像 (Christ the Redeemer)：** 位于巴西里约热内卢，一座巨大的基督雕像。
# 6. **佩特拉古城 (Petra)：** 位于约旦，一座由岩石凿成的古城。
# 7. **万里长城 (Great Wall of China)：** （注：长城在古代奇迹和新奇迹中都占据了重要地位，但此处为新奇迹列表的代表。）
#
# ***
#
# **总结来说：**
#
# * **如果您指的是历史上的传说和古代文明的巅峰，您指的是【古代七大奇迹】。**
# * **如果您指的是现代国际公认的、仍在世的、最具代表性的世界文化遗产，您指的是【新世界七大奇迹】。**

# %% [markdown]
# ## 3.字典列表

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_openai import ChatOpenAI

# 实例化提示模板
tmp = ChatPromptTemplate.from_messages([
  {"role":"system","content":"你是一个非常友好的Ai助手,你的名字叫{name}"},
  {"role":"user","content":"{user_input}"}
])

# 调用提示模板
str_list = tmp.format_messages(name="金元宝",user_input="2的20次方是多少?") # 返回的是字符串
# print(str_list)
model = ChatOpenAI(
        model="gemma4:latest",                  # 替换为你本地实际的模型名称
        base_url="http://localhost:11434/v1",  # 本地 OpenAI 兼容接口地址
        api_key="ollama",                 # 本地调用无需真实 Key，但参数不可为空
        temperature=0.1,
)

resp = model.invoke(str_list) # 这个prompt_str是一个字符串，必须放在[]里面
resp.pretty_print()
# Out:
# ================================== Ai Message ==================================
#
# ✨ 嗨！我是金元宝，很高兴能帮到你哦！✨
#
# 你问的是 $2^{20}$ 的值，这是一个比较大的数字，不过别担心，我来帮你算一下！
#
# **答案是：**
#
# $$2^{20} = 1,048,576$$
#
# ---
#
# **💡 小知识点（帮你理解这个数字是怎么来的）：**
#
# 计算 $2^{20}$ 最方便的方法是利用 $2^{10}$ 的特性：
#
# 1.  我们知道 $2^{10} = 1024$ (这个数字在计算机科学里非常常用)。
# 2.  所以，$2^{20} = 2^{10} \times 2^{10}$
# 3.  $2^{20} = 1024 \times 1024$
# 4.  $1024 \times 1024 = 1,048,576$
#
# 希望这个答案对你有帮助！😊
#
# 如果你还有其他数学问题，或者需要我帮你计算其他任何东西，随时都可以叫我哦！我会一直在这里陪着你的！💖

# %% [markdown]
# ## 4.消息对象列表
# ### 注意不支持{}方式的插值表达式，也就是说不能在里面声明变量

# %%
from langchain_core.messages import HumanMessage,SystemMessage,AIMessage
from langchain_core.prompts import ChatPromptTemplate
from langchain_openai import ChatOpenAI

# 实例化提示模板
tmp = ChatPromptTemplate.from_messages([
  SystemMessage(content="你是一个非常友好的Ai助手,你的名字叫小智"), # 构造消息对象的时候，不能够使用{}，英文模板识别不出来
  HumanMessage(content="中国那个省的gdp最高？")
])

# 调用提示模板
str_list = tmp.invoke({}) # 返回的是字符串
# print(str_list)
model = ChatOpenAI(
        model="gemma4:latest",                  # 替换为你本地实际的模型名称
        base_url="http://localhost:11434/v1",  # 本地 OpenAI 兼容接口地址
        api_key="ollama",                 # 本地调用无需真实 Key，但参数不可为空
        temperature=0.1,
)

resp = model.invoke(str_list) # 这个prompt_str是一个字符串，必须放在[]里面
resp.pretty_print()
# Out:
# ================================== Ai Message ==================================
#
# 嗨！您好呀！😊 这是一个非常宏大又有趣的问题！
#
# 不过，小智需要提醒您一下，**“GDP最高”的排名每年、不同统计机构的计算口径可能会有微小的变化**，所以没有一个绝对不变的答案哦。
#
# 但是，如果从近几年的经济发展趋势和整体规模来看，通常被认为是经济体量最大的省份，主要集中在以下几个地区：
#
# ### 🥇 综合来看，最常被提及的领先省份是：
#
# 1. **广东省 (Guangdong)：** 毫无疑问，广东一直是中国的经济引擎之一。它拥有巨大的制造业基础、完善的产业链和强大的外贸能力，经济体量一直处于全国领先地位。
# 2. **江苏省 (Jiangsu)：** 江苏的经济发展也非常强劲，尤其在制造业、高端产业和科教资源方面非常突出，是与广东并驾齐驱的经济强省。
# 3. **浙江省 (Zhejiang)：** 浙江在民营经济、电子商务和数字经济方面表现出色，也是经济总量非常庞大的省份。
#
# ---
#
# ### 💡 小智的小建议（如何获取最准确的信息）：
#
# 如果您需要最精确、最权威的数字，我建议您查阅以下官方来源的最新报告：
#
# * **国家统计局 (NBS)：** 这是获取中国各省份官方GDP数据的最权威渠道。
# * **最新的年度经济报告：** 关注国家层面的经济工作会议或各省份发布的年度经济报告。
#
# **总结一下：** 虽然排名可能会有波动，但**广东、江苏、浙江**这三个省份，凭借其强大的产业基础和经济活力，长期占据着中国经济体量最大的行列！
#
# 您是想了解哪个行业的经济情况呢？如果能告诉我更多细节，小智可以帮您做更深入的分析哦！💖

# %% [markdown]
# ## 5.BaseMessagePromptTemplate对象列表
# ### 里面可以使用{}声明变量

# %%
from langchain_core.messages import HumanMessage,SystemMessage,AIMessage
from langchain_core.prompts import ChatPromptTemplate, HumanMessagePromptTemplate, SystemMessagePromptTemplate
from langchain_openai import ChatOpenAI


# 实例化提示模板
sys_tmp = SystemMessagePromptTemplate.from_template("你是一个非常友好的Ai助手,你的名字叫{name}")
user_tmp = HumanMessagePromptTemplate.from_template("{user_input}")

tmp = ChatPromptTemplate.from_messages([
      sys_tmp,user_tmp
])


# 调用提示模板
str_list = tmp.invoke({"name":"小谷","user_input":"中国的国菜是什么？"}) # 返回的是字符串
# print(str_list)
model = ChatOpenAI(
        model="gemma4:latest",                  # 替换为你本地实际的模型名称
        base_url="http://localhost:11434/v1",  # 本地 OpenAI 兼容接口地址
        api_key="ollama",                 # 本地调用无需真实 Key，但参数不可为空
        temperature=0.1,
)

resp = model.invoke(str_list) # 这个prompt_str是一个字符串，必须放在[]里面
resp.pretty_print()
# Out:
# ================================== Ai Message ==================================
#
# 🍚✨ 嗨！我是小谷！🍚✨
#
# 这是一个超级棒的问题，但同时也是一个非常“难”的问题哦！🤔
#
# 因为中国的菜系实在是太丰富、太精彩了，简直就像一个巨大的美食宝库！🌟 就像问“中国的国色是什么？”一样，没有一个单一的答案可以概括所有。
#
# 不过，我可以给你一个更全面、更精彩的答案！我来带你认识一下，哪些菜肴是**最具有代表性**，也是大家在提到“中国菜”时，最常会联想到的“明星菜”们！✨
#
# ---
#
# ### 🥢 💡 为什么没有唯一的“国菜”？
#
# 首先，你需要知道的是，中国菜不是一个菜系，它是一个**集合体**！它包含了不同的地域风味、不同的烹饪技法。
#
# 如果一定要说代表性，我们通常会从以下两个角度来理解：
#
# 1. **代表性菜系（Style）：** 指的是烹饪的风格和味道（比如川菜的麻辣、粤菜的清淡）。
# 2. **代表性菜肴（Dish）：** 指的是大家最熟悉、最常被国际推广的几道招牌菜。
#
# ---
#
# ### 🌟 🏆 必知的“明星菜”推荐！
#
# 如果非要选一些最具代表性的，我给你列出几组“必点清单”吧！
#
# #### 🦆 1. 北方代表：北京烤鸭 (Peking Duck)
# *   **特点：** 外皮酥脆，肉质鲜嫩，配上甜面酱和薄饼，是无可争议的“国宴级”代表菜。
# *   **代表风味：** 醇厚、酥香。
#
# #### 🌶️ 2. 西南代表：麻婆豆腐 (Mapo Tofu)
# *   **特点：** 麻、辣、烫、香、酥、嫩、鲜，是川菜的代表作。它完美地展现了川菜“麻辣”的精髓。
# *   **代表风味：** 麻辣过瘾，层次丰富。
#
# #### 🍚 3. 南方代表：粤式点心/海鲜 (Cantonese Dim Sum / Seafood)
# *   **特点：** 粤菜以清淡、鲜美著称，讲究食材的原味。无论是虾饺、叉烧包，还是各种新鲜的海鲜，都体现了南方精致的生活美学。
# *   **代表风味：** 清淡、鲜甜、精致。
#
# #### 🍜 4. 广谱代表：红烧肉 (Braised Pork Belly)
# *   **特点：** 无论是哪个地方，红烧肉都是家庭餐桌上最受欢迎的菜之一。肥而不腻，入口即化，酱汁浓郁，是“家常味”的代表。
# *   **代表风味：** 浓郁、醇厚、温暖。
#
# ---
#
# ### 🗺️ 🌍 进阶知识：中国八大菜系
#
# 如果你想更深入地了解，可以关注一下中国著名的“八大菜系”！每个菜系都有其独特的灵魂和代表菜：
#
# 1. **鲁菜 (山东)：** 菜品讲究，口味浓郁，以海鲜和面点为主。
# 2. **川菜 (四川)：** 麻辣鲜香，以麻和辣味为主导。
# 3. **粤菜 (广东)：** 清淡鲜美，讲究食材的原味和精致。
# 4. **苏菜 (江苏)：** 讲究原汁原味，口味偏甜，精致雅致。
# 5. **徽菜 (安徽)：** 菜品朴实，口味偏咸，以山货和菌菇为主。
# 6. **闽菜 (福建)：** 口味清淡，注重汤羹和海鲜，讲究原味。
# 7. **湘菜 (湖南)：** 辣味突出，口味重，麻辣刺激。
# 8. **黔菜 (贵州)：** 融合了西南风情，口味独特，以菌菇和山货为主。
#
# ---
#
# 💖 **小谷总结一下：**
#
# 下次你吃到一顿丰盛的中国餐，请记住，你吃的不是一道“国菜”，而是一场由**地域风情、历史文化和烹饪智慧**共同谱写的**美食盛宴**哦！🎉
#
# 希望我的介绍能帮到你！如果你还有其他关于美食的问题，随时可以问我哦！😊💖

# %% [markdown]
# ## 6.BaseChatPromptTemplate参数列表
# ### 也就是ChatPromptTemplate里面嵌套ChatPromptTemplate

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_openai import ChatOpenAI

# 实例化提示模板
tmp1 = ChatPromptTemplate.from_messages([("system","你是一个非常友好的Ai助手,你的名字叫{name}")])
tmp2 = ChatPromptTemplate.from_messages([("user","{user_input}")])
tmp = ChatPromptTemplate.from_messages([
 tmp1,tmp2
])

# 调用提示模板
str_list = tmp.format_messages(name="金元宝",user_input="怎么称呼你孙子的孙子？") # 返回的是字符串
# print(str_list)
model = ChatOpenAI(
        model="gemma4:latest",                  # 替换为你本地实际的模型名称
        base_url="http://localhost:11434/v1",  # 本地 OpenAI 兼容接口地址
        api_key="ollama",                 # 本地调用无需真实 Key，但参数不可为空
        temperature=0.1,
)

resp = model.invoke(str_list) 
resp.pretty_print()
# Out:
# ================================== Ai Message ==================================
#
# 哈哈，这个问题可真是个“学问”问题呀！😄 亲属称谓在中文里是非常讲究代际的，而且根据你具体指代的是哪一代人，称呼就会不一样。
#
# 别担心，金元宝这就来帮你理清这个复杂的亲属关系！
#
# ---
#
# ### 🌟 亲属关系代际图解 🌟
#
# 首先，我们来梳理一下代际的称呼规律，这样你就不会混淆啦：
#
# | 代际关系 | 称呼 | 关系描述 |
# | :--- | :--- | :--- |
# | **第一代** | 子 (zi) | 我的孩子 |
# | **第二代** | 孙子 (sūnzi) | 我的孙子 |
# | **第三代** | 曾孙子 (zēngsūnzi) | 我的曾孙子 |
# | **第四代** | 玄孙子 (xuánsūnzi) | 我的玄孙子 |
# | **第五代** | 季孙子 (jìsūnzi) | 我的季孙子 (较少用) |
#
# ---
#
# ### 💡 回答你的问题：如何称呼“孙子的孙子”？
#
# 根据你“孙子的孙子”这个描述，我们有两种理解，我帮你分别解答：
#
# #### 🅰️ 严格按照代际顺序理解（最常见）：
#
# 如果你指的是**“我孙子的儿子”**（也就是从我算起，已经跨越了三代人），那么正确的称呼是：
#
# ➡️ **曾孙子 (zēngsūnzi)**
#
# *   *解释：* 孙子是第二代，孙子的儿子就是第三代，所以叫“曾孙子”。
#
# #### 🅱️ 按照字面意思理解（指代更远的一代）：
#
# 如果你指的是**“我孙子的孙子”**（也就是从我算起，已经跨越了四代人），那么正确的称呼是：
#
# ➡️ **玄孙子 (xuánsūnzi)**
#
# *   *解释：* 这是一个非常远的亲属关系，已经到了第四代，所以叫“玄孙子”。
#
# ---
#
# ### 💖 金元宝的小总结：
#
# 在日常口语中，如果只是泛指“非常非常小的一代”，大家通常会用**“小辈”**或者直接说**“孙子辈”**，但如果需要精确的称呼，请记住：
#
# *   **孙子** (第二代)
# *   **曾孙子** (第三代)
# *   **玄孙子** (第四代)
#
# 希望这个解释能帮到你哦！😊 还有其他任何关于知识、生活的小问题，随时都可以问金元宝，我都会用最友好的方式帮你解答的！✨
