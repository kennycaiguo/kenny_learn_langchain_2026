# %%
import os
from langchain_openai import ChatOpenAI
from dotenv import load_dotenv

load_dotenv(override=True)
from weather_tool import query_weather

weather_data = query_weather()  
model = ChatOpenAI(
    model="qwen2.5vl:latest",
    api_key="sk12345",
    base_url="http://localhost:11434/v1",
    temperature=0.1
)   

messages = [
    {"role": "system", "content": "这是当前北京市的实时天气数据：%s, 来源于OpenWeather API：https://api.openweathermap.org/data/2.5/weather" %weather_data},
    {"role": "user", "content": "请问：当前北京市的天气如何？"} 
]    

resp = model.invoke(messages)
resp.pretty_print()
# Out:
# ================================== Ai Message ==================================
#
# 当前北京市的天气情况如下：
#
# - 天气状况：多云
# - 感知温度：22.36°C
# - 实际温度：21.94°C
# - 湿度：83%
# - 风速：1.99米/秒
# - 风向：82度
# - 可见度：10000米
# - 云层覆盖：37%
# - 当前时间：1789671420秒（需转换为北京时间）
# - 日出时间：1789682263秒（需转换为北京时间）
# - 日落时间：1789726797秒（需转换为北京时间）
# - 城市ID：1816670
# - 城市名称：Beijing
# - 状态码：200（表示请求成功）

# %%
import os
from langchain_openai import ChatOpenAI
import requests
from dotenv import load_dotenv

load_dotenv(override=True)


def query_weather_web(city="广州", aqi="no", language="zh_cn"):
     appid = os.getenv("Weather_api_key")
     # 构建请求URL
     url = "https://api.weatherapi.com/v1/current.json"
     # 设置查询参数
     params = {
         "q": city,                 # 查询的城市，默认为北京
         "key": appid,          # API密钥
         "aqi": aqi,            # 测量单位，默认为摄氏度
         "lang": language           # 输出语言，默认为简体中文
     }
     # 发送GET请求
     response = requests.get(url, params=params)
     # 检查响应状态
     if response.status_code == 200:
         # 解析响应数据
         data = response.json()
        #  # 打印获取到的数据
        #  print(f"查询城市: {city}")
        #  print(f"温度: {data['main']['temp']}°{units[0].upper()}")
        #  print(f"天气描述: {data['weather'][0]['description']}")
        #  print(f"湿度: {data['main']['humidity']}%")
        #  print(f"风速: {data['wind']['speed']} m/s")
         
         return data
     
     else:
         print(f"查询失败，状态码：{response.status_code}")
         print("响应数据：", response.text)
         return {"error":"weather api 调用失败。。。"}

query_weather_web("东莞")
# Out:
# {'location': {'name': '东莞',
#   'region': 'Guangdong',
#   'country': '中国',
#   'lat': 23.0489,
#   'lon': 113.7447,
#   'tz_id': 'Asia/Shanghai',
#   'localtime_epoch': 1789754209,
#   'localtime': '2026-09-19 01:56'},
#  'current': {'last_updated_epoch': 1789753500,
#   'last_updated': '2026-09-19 01:45',
#   'temp_c': 28.0,
#   'temp_f': 82.4,
#   'is_day': 0,
#   'condition': {'text': 'Smoky haze',
#    'icon': '//cdn.weatherapi.com/weather/64x64/night/149.png',
#    'code': 1036},
#   'wind_mph': 2.2,
#   'wind_kph': 3.6,
#   'wind_degree': 175,
#   'wind_dir': 'S',
#   'pressure_mb': 1014.0,
#   'pressure_in': 29.95,
#   'precip_mm': 0.0,
#   'precip_in': 0.0,
#   'humidity': 71,
#   'cloud': 4,
#   'feelslike_c': 30.8,
#   'feelslike_f': 87.4,
#   'windchill_c': 28.0,
#   'windchill_f': 82.4,
#   'heatindex_c': 31.0,
#   'heatindex_f': 87.8,
#   'dewpoint_c': 22.2,
#   'dewpoint_f': 72.0,
#   'vis_km': 5.2,
#   'vis_miles': 3.0,
#   'uv': 0.0,
#   'gust_mph': 3.8,
#   'gust_kph': 6.2,
#   'will_it_rain': 0,
#   'chance_of_rain': 6,
#   'will_it_snow': 0,
#   'chance_of_snow': 0,
#   'wetbulb_c': 23.8,
#   'wetbulb_f': 74.9}}
