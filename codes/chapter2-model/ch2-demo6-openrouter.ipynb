# %% [markdown]
# # 使用OpenRouter中转平台来调用大模型，在国内的话需要梯子
# ### 需要安装对应的库： pip install langchain-openrouter

# %%
from dotenv import load_dotenv
import os
from langchain_openrouter import ChatOpenRouter

load_dotenv(override=True)
OPENROUTER_API_KEY = os.getenv("OPENROUTER_API_KEY")
OPENROUTER_API_BASE = os.getenv("OPENROUTER_API_BASE")

llm = ChatOpenRouter(
    model="glm-5.3-flash",
    api_key=OPENROUTER_API_KEY,
    base_url=OPENROUTER_API_BASE
)

resp = llm.invoke("奇门遁甲是什么")
print(resp.text)
# Out:
# # 奇门遁甲简介
#
# 奇门遁甲是中国古代的一门术数学问，与**太乙**、**六壬**并称“三式”，被认为是中国传统预测学中体系最庞大、结构最复杂的一门，素有“帝王之学”之称。
#
# ## 名称由来
#
# - **奇**：指乙、丙、丁三奇，是天干中三个特殊的天干
# - **门**：指休、生、伤、杜、景、死、惊、开八门
# - **遁甲**：甲为天干之首，被视为最尊贵，须“遁”(隐藏)于六仪(戊、己、庚、辛、壬、癸)之下
#
# ## 历史渊源
#
# 传说中奇门遁甲源于黄帝战蚩尤，后经姜太公、张良、诸葛亮、刘伯温等传承完善。从史实角度看，它是历代术数家不断丰富发展起来的，其成熟形态大约定型于唐宋时期。古代主要用于**军事谋略**，后来逐渐扩展到民用领域。
#
# ## 基本构成
#
# 奇门遁甲以洛书九宫为框架，融合了：
#
# - **九星**：天蓬、天任、天冲、天辅、天英、天芮、天柱、天心、天禽
# - **八门**：休、生、伤、杜、景、死、惊、开
# - **八神**：值符、腾蛇、太阴、六合、白虎、玄武、九地、九天
# - **三奇六仪**与天干地支系统
#
# 排盘时根据年、月、日、时的时间信息和方位空间信息，将以上要素组合布局，分为**阳遁九局**和**阴遁九局**。
#
# ## 主要用途
#
# 1. **预测占断**：分析事务的成败吉凶
# 2. **择时择方**：选择有利的时机和方位(古时用于行军布阵、出征择日)
# 3. **决策辅助**：现代有人将其应用于商业决策、人事分析等
#
# ## 文化影响
#
# 奇门遁甲在民间传说和文学影视作品中常被神化为“呼风唤雨、撒豆成兵”的法术(如电影《奇门遁甲》)。实际上，传统意义上的奇门遁甲是一套基于时间和空间的**符号推演系统**，反映了中国古代的宇宙观和时空观念，是研究中国传统文化和术数学不可绕过的一环。
#
# 你是想了解它的具体排盘方法，还是对某个方面(如历史、应用)更感兴趣？

# %%
from dotenv import load_dotenv
import os
from langchain_openrouter import ChatOpenRouter

load_dotenv(override=True)
OPENROUTER_API_KEY = os.getenv("OPENROUTER_API_KEY")
OPENROUTER_API_BASE = os.getenv("OPENROUTER_API_BASE")

llm = ChatOpenRouter(
    model="deepseek/deepseek-v4-flash",
    api_key=OPENROUTER_API_KEY,
    base_url=OPENROUTER_API_BASE
)

resp = llm.invoke("奇门遁甲是什么")
print(resp.text)
# Out:
# 奇门遁甲是中国古代一种结合天文、历法、阴阳五行、易经八卦等多种理论的综合性术数体系。它起源于古代军事谋略，后来逐渐发展用于预测、决策和风水等领域。奇门遁甲的核心是通过天、地、人、神四个维度的符号系统（包括九星、八门、八神、九宫等），模拟时空变化与事物发展的规律，从而推演吉凶、选择时机方位。它被列为“道家五术”之一，与太乙神数、大六壬并称“三式”。现代更多被视为传统文化中的玄学遗产或哲学工具。

# %%
from langchain_openrouter import ChatOpenRouter
from dotenv import load_dotenv
import os

load_dotenv(override=True)
OPENROUTER_API_KEY = os.getenv("OPENROUTER_API_KEY2")
OPENROUTER_API_BASE = os.getenv("OPENROUTER_API_BASE")

llm = ChatOpenRouter(
    model="gemini-3.1-flash-lite",
    api_key=OPENROUTER_API_KEY,
    base_url=OPENROUTER_API_BASE
)

resp = llm.invoke("简单介绍一下你自己")
print(resp.text)
# Out:
# ---------------------------------------------------------------------------
# PaymentRequiredResponseError              Traceback (most recent call last)
# Cell In[7], line 15
#      11     api_key=OPENROUTER_API_KEY,
#      12     base_url=OPENROUTER_API_BASE
#      13 )
#      14
# ---> 15 resp = llm.invoke("简单介绍一下你自己")
#      16 print(resp.text)
#
# File ~\anaconda3\envs\langchain1.2\Lib\site-packages\langchain_core\language_models\chat_models.py:488, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     474 @override
#     475 def invoke(
#     476     self,
#    (...)    481     **kwargs: Any,
#     482 ) -> AIMessage:
#     483     config = ensure_config(config)
#     484     return cast(
#     485         "AIMessage",
#     486         cast(
#     487             "ChatGeneration",
# --> 488             self.generate_prompt(
#     489                 [self._convert_input(input)],
#     490                 stop=stop,
#     491                 callbacks=config.get("callbacks"),
#     492                 tags=config.get("tags"),
#     493                 metadata=config.get("metadata"),
#     494                 run_name=config.get("run_name"),
#     495                 run_id=config.pop("run_id", None),
#     496                 **kwargs,
#     497             ).generations[0][0],
#     498         ).message,
#     499     )
#
# File ~\anaconda3\envs\langchain1.2\Lib\site-packages\langchain_core\language_models\chat_models.py:1877, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1868 @override
#    1869 def generate_prompt(
#    1870     self,
#    (...)   1874     **kwargs: Any,
#    1875 ) -> LLMResult:
#    1876     prompt_messages = [p.to_messages() for p in prompts]
# -> 1877     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File ~\anaconda3\envs\langchain1.2\Lib\site-packages\langchain_core\language_models\chat_models.py:1684, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#    1681 for i, m in enumerate(input_messages):
#    1682     try:
#    1683         results.append(
# -> 1684             self._generate_with_cache(
#    1685                 m,
#    1686                 stop=stop,
#    1687                 run_manager=run_managers[i] if run_managers else None,
#    1688                 **kwargs,
#    1689             )
#    1690         )
#    1691     except BaseException as e:
#    1692         if run_managers:
#
# File ~\anaconda3\envs\langchain1.2\Lib\site-packages\langchain_core\language_models\chat_models.py:2022, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    2020     result = generate_from_stream(iter(chunks))
#    2021 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 2022     result = self._generate(
#    2023         messages, stop=stop, run_manager=run_manager, **kwargs
#    2024     )
#    2025 else:
#    2026     result = self._generate(messages, stop=stop, **kwargs)
#
# File ~\anaconda3\envs\langchain1.2\Lib\site-packages\langchain_openrouter\chat_models.py:572, in ChatOpenRouter._generate(self, messages, stop, run_manager, **kwargs)
#     570 params = {**params, **kwargs}
#     571 _strip_internal_kwargs(params)
# --> 572 response = self.client.chat.send(messages=message_dicts, **params)
#     573 return self._create_chat_result(response)
#
# File ~\anaconda3\envs\langchain1.2\Lib\site-packages\openrouter\chat.py:882, in Chat.send(self, messages, http_referer, x_open_router_title, x_open_router_categories, x_open_router_metadata, cache_control, debug, frequency_penalty, image_config, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, min_p, modalities, model, models, parallel_tool_calls, plugins, prediction, presence_penalty, prompt_cache_key, prompt_cache_options, provider, reasoning, reasoning_effort, repetition_penalty, response_format, seed, service_tier, session_id, stop, stop_server_tools_when, stream, stream_options, temperature, tool_choice, tools, top_a, top_k, top_logprobs, top_p, trace, user, retries, server_url, timeout_ms, http_headers)
#     878     http_res_text = utils.stream_to_text(http_res)
#     879     response_data = unmarshal_json_response(
#     880         errors.PaymentRequiredResponseErrorData, http_res, http_res_text
#     881     )
# --> 882     raise errors.PaymentRequiredResponseError(
#     883         response_data, http_res, http_res_text
#     884     )
#     885 if utils.match_response(http_res, "403", "application/json"):
#     886     http_res_text = utils.stream_to_text(http_res)
#
# PaymentRequiredResponseError: This request requires more credits, or fewer max_tokens. You requested up to 65536 tokens, but can only afford 26666. To increase, visit https://openrouter.ai/settings/credits and upgrade to a paid account
