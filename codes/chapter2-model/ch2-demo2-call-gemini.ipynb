# %% [markdown]
# # 调用Google的Gemini大模型
# ## pip install google-genai
# ### 注意，gemini-2.x-xx的模型已经不给新用户使用了，
# ### 可以使用：gemini-3.5-flash或者gemini-3.1-flash-lite

# %%
# 使用genai接口
import os
from dotenv import load_dotenv
from google import genai

load_dotenv(override=True)
gemini_api_key = os.getenv("gemini_api_key")
client = genai.Client(api_key=gemini_api_key)
resp = client.models.generate_content(
    model="gemini-3.1-flash-lite",
    contents=["Define autonomous AI agent in one line."]
)

print(resp.text)
# Out:
# An autonomous AI agent is a software system capable of perceiving its environment, reasoning, and executing a sequence of actions independently to achieve predefined goals without continuous human intervention.

# %%
# 使用openai接口
import os
from dotenv import load_dotenv
from openai import OpenAI

load_dotenv(override=True)
gemini_api_key = os.getenv("gemini_api_key")
client = OpenAI(api_key=gemini_api_key,base_url="https://generativelanguage.googleapis.com/v1beta/openai/")
resp = client.chat.completions.create(
     model="gemini-3.1-flash-lite",
     messages=[{
         "role":"user","content":"腾讯是一家什么样的公司？" # 可以用中文想gemini提问，它也能够回答上来
     }]
)
    


print(resp.choices[0].message.content)
# Out:
# 腾讯（Tencent）是一家总部位于中国深圳的**互联网综合服务提供商**，也是全球规模最大的互联网科技公司之一。
#
# 要理解腾讯，可以从以下几个维度来看：
#
# ### 1. 核心商业模式：社交与流量的“连接器”
# 腾讯的商业逻辑基石是**社交**。
# *   **社交帝国：** 腾讯拥有中国国民级的通讯软件——**微信（WeChat）**和**QQ**。这两款产品不仅是聊天工具，更是中国数字生活的“基础设施”。微信连接了人与人、人与服务、人与商业，构建了一个庞大的生态系统（如微信支付、小程序）。
# *   **流量分发：** 凭借微信和QQ庞大的用户基础，腾讯成为了中国互联网最大的“流量入口”。几乎所有的互联网服务（电商、游戏、新闻、内容）都需要通过腾讯的生态来获取用户。
#
# ### 2. 核心业务板块
# 腾讯的业务极其广泛，通常被称为“帝国”：
# *   **游戏（现金奶牛）：** 腾讯是**全球最大的游戏公司**。它拥有《王者荣耀》、《和平精英》等自研大作，同时通过投资和收购控股了如《英雄联盟》开发商拳头公司（Riot Games）、持有Epic Games（《堡垒之夜》）和动视暴雪等巨头的大量股份。
# *   **数字内容：** 腾讯拥有强大的内容矩阵，包括腾讯视频、腾讯音乐、阅文集团（网络文学）、腾讯动漫等，覆盖了用户娱乐生活的方方面面。
# *   **金融科技与企业服务：** 微信支付是腾讯的核心支柱之一，占据中国移动支付的半壁江山。此外，腾讯云也在持续发力，为企业提供数字化转型方案（即“产业互联网”）。
# *   **投资业务：** 腾讯被称为“中国互联网的顶级风投”。它通过投资入股了美团、拼多多、京东、快手等众多中国互联网巨头，形成了一个庞大的“腾讯系”阵营。
#
# ### 3. 公司定位与哲学：从“连接一切”到“助力实体”
# *   **连接一切（2011年左右）：** 腾讯早期的使命是做互联网的连接器，让每个人都能通过腾讯的产品接入互联网。
# *   **助力实体（产业互联网）：** 近年来，腾讯将战略重心转向“为各行各业提供数字化的工具箱”，强调“科技向善”，即强调科技发展应与社会利益保持一致。
#
# ### 4. 企业形象的评价
# *   **正面：**
#     *   **极强的产品能力：** 腾讯的产品逻辑和用户体验设计被公认为中国一流。
#     *   **生态强大：** 在微信生态内可以完成社交、支付、购物、打车、看病挂号等，极大地便利了人们的生活。
#     *   **技术底座：** 在即时通讯、高并发处理、音视频技术等方面拥有世界级的技术储备。
# *   **负面/争议：**
#     *   **“垄断”争议：** 过去曾因滥用市场支配地位（如“二选一”策略、屏蔽竞争对手链接）受到反垄断监管的审查，目前已在逐步规范。
#     *   **抄袭历史：** 在腾讯发展的早期，因模仿竞争对手产品（“像素级模仿”）而备受诟病，但近年来其研发创新投入已大幅增加。
#     *   **青少年游戏沉迷：** 作为游戏巨头，腾讯在防沉迷系统和未成年人保护方面常处于舆论风口浪尖。
#
# ### 总结
# **腾讯是一家靠“社交+内容+资本”驱动的巨型数字生态公司。**
#
# 如果把互联网比作一座城市，腾讯既是这座城市里最繁忙的**交通枢纽**（微信/QQ），又是最大的**娱乐中心**（游戏/视频/文学），还是最大的**金融结算中心**（微信支付）。它深度融入了当代中国人的日常生活，是观察中国互联网乃至中国经济活力的一个最重要的窗口。

# %% [markdown]
# # 用openai兼容语法调用gemini
# ## 注意：使用langchain_openai里面的ChatOpenAI，不要使用langchain-community里面的ChatOpenAI，因为它已经过时了

# %%
from langchain_openai import ChatOpenAI
from dotenv import load_dotenv
import os

load_dotenv(override=True)
gemini_api_key = os.getenv("gemini_api_key")

llm = ChatOpenAI(
    model="gemini-3.1-flash-lite",
    api_key=gemini_api_key,
    base_url="https://generativelanguage.googleapis.com/v1beta/openai/"
)

resp = llm.invoke("花花公子是什么")
print(resp.text)
# Out:
# “花花公子”这个词在中文语境中有几个不同的层面，主要可以从**文化符号、杂志品牌、性格特征**三个方面来理解：
#
# ### 1. 作为性格特征（Playboy）
# 在日常生活中，“花花公子”通常用来形容那些**对感情不专一、风流成性、喜欢周旋于多位女性之间、注重享受和生活品质的男性**。
# *   **核心特质：** 通常被认为具有魅力、谈吐幽默、外表光鲜，且往往财力雄厚或善于社交。
# *   **褒贬色彩：** 带有一定的贬义，暗示其对感情缺乏责任感，但也隐含了一点对这种生活方式的某种“羡慕”或“猎奇”心理。
#
# ### 2. 作为文化与商业品牌（Playboy Magazine）
# “花花公子”最广为人知的身份是美国著名杂志**《花花公子》（Playboy）**。
# *   **创立：** 由休·赫夫纳（Hugh Hefner）于1953年在美国创办。
# *   **内容与定位：** 这本杂志以刊登性感美女照片（“兔女郎”造型是其标志）而闻名，但它不仅仅是一本成人杂志。它在当时的美国社会具有极高的文化影响力，常刊登深度访谈（采访过许多社会名流、政客、作家）、小说、时尚指南和生活方式建议。
# *   **文化象征：** 它在20世纪60年代的美国被视为“性解放”运动的象征，代表了一种推崇自由、享乐主义、反抗传统束缚的都市男性生活方式。
# *   **商业符号：** “兔头”Logo是世界上辨识度最高的品牌Logo之一，出现在各类服装、香水、配饰等周边产品上。
#
# ### 3. 词语演变与现状
# *   **历史背景：** 在20世纪中叶，“花花公子”代表了一种理想的、精致的都市生活方式（Sophisticated lifestyle），即一个男人应该如何品酒、穿着、欣赏艺术和与人交往。
# *   **现代语境：** 随着时代变化，“花花公子”的形象受到了不少批评。尤其是在女性主义浪潮中，人们认为该品牌及其所代表的男性视角存在对女性的物化（Objectification）。
# *   **品牌转型：** 近年来，随着互联网的冲击和价值观的转变，传统的纸质成人杂志已经不再是商业核心。现在的《花花公子》更多是以一个**全球性的生活方式品牌**出现，其业务重心转向了品牌授权、娱乐和衍生品。
#
# ### 总结
# 简单来说：
# *   如果你是在**聊天中听到有人被叫“花花公子”**，那是在指责他**花心、留情**。
# *   如果你是看到**衣服或包包上的“兔头”Logo**，那是指那个著名的**商业品牌**。
# *   如果你是在**历史或文化讨论中**听到，那通常指那个**曾经改变了美国流行文化、推崇“性解放”和“享乐主义”的现象级品牌**。
