# %% [markdown]
# ## 模型有很多参数，比较重要的有temperature，取值0.0-2.0 数值越大，越有创造了。数值越小越稳定

# %%
from langchain.chat_models import init_chat_model
from dotenv import load_dotenv
import os

from openai import api_key

load_dotenv(override=True)
gemini_api_key=os.getenv("gemini_api_key")

# model = init_chat_model("openai:gpt-4o", temperature=0)
model = init_chat_model("google_genai:gemini-3.1-flash-lite",api_key=gemini_api_key, temperature=1.5)

# Invoke the model with a simple message
response = model.invoke("写一首关于春天的七言绝句")
print(response.text)
# Out:
# Direct use of automatic function calling (AFC) in Models.generate_content is not recommended. Instead, we recommend to use AFC in Chat.send_message. Similarly, direct use of AFC in Models.generate_content_stream is not recommended. Instead, we recommend to use AFC in Chat.send_message_stream.
# 为您创作了一首描写春天的七言绝句：
#
# **《春日》**
#
# **草色青青柳线长，东风拂过百花香。**
# **莺啼燕语寻芳去，又是人间好景光。**
#
# ---
# **赏析：**
# 这首诗描绘了春天生机勃勃的景象：碧绿的草地映衬着柳条轻摆，东风吹送着花朵的芬芳。黄莺鸣叫，燕子穿梭，仿佛在忙着寻访春光。全诗表达了对春日美好景色的喜爱与赞美。

# %% [markdown]
# ## 严格结构化数据提取

# %%
from langchain.chat_models import init_chat_model
from dotenv import load_dotenv
import os

from openai import api_key

load_dotenv(override=True)
gemini_api_key=os.getenv("gemini_api_key")

# model = init_chat_model("openai:gpt-4o", temperature=0)
model = init_chat_model("google_genai:gemini-3.1-flash-lite",api_key=gemini_api_key, temperature=1.5)

# Invoke the model with a simple message
response = model.invoke("小明,女,30岁,拥有8年编程开发经验,目前在谋互联网大厂担任技术专家.帮我从上文中提取数据,返回JSON格式"
)
print(response.text)
# Out:
# 根据您提供的信息，提取的JSON数据如下：
#
# ```json
# {
#   "姓名": "小明",
#   "性别": "女",
#   "年龄": 30,
#   "工作经验": "8年",
#   "职业领域": "编程开发",
#   "当前职位": "技术专家",
#   "公司类型": "互联网大厂"
# }
# ```

# %% [markdown]
# ## 创意文案与头脑风暴

# %%
from langchain.chat_models import init_chat_model
from dotenv import load_dotenv
import os

from openai import api_key

load_dotenv(override=True)
gemini_api_key=os.getenv("gemini_api_key")

# model = init_chat_model("openai:gpt-4o", temperature=0)
model = init_chat_model("google_genai:gemini-3.1-flash-lite",api_key=gemini_api_key, temperature=1.9)

# Invoke the model with a simple message
response = model.invoke("请为一款极致静音的机械键盘写3个充满诗意且极具张力的广告语")
print(response.text)
# Out:
# 为了展现这款键盘“极致静音”与“机械手感”并存的张力，我们可以从**“消失的噪音”、“沉浸的深海”与“轻盈的叙事”**三个维度来构思：
#
# ### 1. 虚无美学风（强调极致安静带来的震撼）
# > **“所有的喧嚣在此刻闭口，唯有文字，在静谧的真空里起舞。”**
# *   **解读：** 将键盘的静音性能比作“真空”，消除了世界的干扰，让打字成为一种近乎宗教式的纯粹仪式，强调一种“寂静中惊雷”的反差张力。
#
# ### 2. 空间转换风（强调沉浸式体验的跨越）
# > **“按下那一刻，世界的时针归零；我在深海般的宁静里，凿开光影的缝隙。”**
# *   **解读：** 使用“深海”来暗示深度降噪的极致表现，将敲击动作形容为“凿开光影”，把冰冷的工业产品升华为一种连接内心的媒介，营造出极具质感的画面感。
#
# ### 3. 诗意哲理风（强调动作与结果的冲突感）
# > **“不必触碰风，亦能写下狂风。这是对世界最优雅的掠夺——无声，却掷地有声。”**
# *   **解读：** 利用“无声”与“掷地有声”的强烈互文，表达即便听不见声音，打字的内容和思考依然有力。这不仅是一款键盘，更像是一位习惯在隐忍中迸发能量的思考者。

# %% [markdown]
# ## max_tokens
# ### 所谓的token，就是用tokenizer把一句话拆开后的单位，一个token=1-1.8个汉字，3-4个字母

# %%
from langchain.chat_models import init_chat_model
from dotenv import load_dotenv
import os

from openai import api_key

load_dotenv(override=True)
gemini_api_key=os.getenv("gemini_api_key")

# model = init_chat_model("openai:gpt-4o", temperature=0)
model = init_chat_model("google_genai:gemini-3.1-flash-lite",api_key=gemini_api_key, temperature=0,max_tokens=15)

# Invoke the model with a simple message
response = model.invoke("用中文简要介绍什么是AI")
print(response.text)
# Out:
# **AI**（Artificial Intelligence），即**人工智能**
