# %% [markdown]
# ## 使用init_chat_model调用gemini大模型
# ### 需要安装langchain-google-genai
# pip install langchain-google-genai

# %%
from langchain.chat_models import init_chat_model
from dotenv import load_dotenv
import os

from openai import api_key

load_dotenv(override=True)
gemini_api_key=os.getenv("gemini_api_key")

# model = init_chat_model("openai:gpt-4o", temperature=0)
model = init_chat_model("google_genai:gemini-3.1-flash-lite",api_key=gemini_api_key, temperature=0)

# Invoke the model with a simple message
response = model.invoke("Facebook是一家什么公司")
print(response.text)
# Out:
# Facebook（现已更名为 **Meta Platforms, Inc.**）是一家总部位于美国加利福尼亚州的跨国科技巨头。
#
# 为了更全面地了解这家公司，可以从以下几个维度来看：
#
# ### 1. 核心业务与产品
# Facebook 最早是一个社交网站，但现在它是一个庞大的互联网生态系统。其核心产品包括：
# *   **社交媒体平台：** Facebook（主应用）、Instagram（图片和短视频分享）、WhatsApp（即时通讯）、Messenger（即时通讯）、Threads（文字社交）。
# *   **广告业务：** 这是 Meta 最主要的收入来源。通过收集用户数据，Meta 为广告商提供极其精准的定向广告投放服务。
# *   **硬件产品：** Meta 正在大力开发硬件，包括 Quest 系列虚拟现实（VR）头显和与雷朋合作的智能眼镜。
#
# ### 2. 战略转型：从“Facebook”到“Meta”
# 2021年10月，公司正式更名为 **Meta**。这一举动标志着公司战略的重大转型：
# *   **元宇宙（Metaverse）：** 公司创始人马克·扎克伯格（Mark Zuckerberg）宣布将公司重心转向构建“元宇宙”，即一个融合了虚拟现实（VR）和增强现实（AR）的沉浸式数字世界。
# *   **品牌重塑：** 更名是为了反映公司不仅仅是一家社交媒体公司，而是一家致力于构建未来计算平台和连接技术的科技公司。
#
# ### 3. 商业模式
# Meta 的商业模式主要依赖于**数字广告**。
# *   它拥有全球数十亿的活跃用户，通过这些用户在平台上的行为（点赞、搜索、停留时间等），Meta 能够构建详细的用户画像，从而向广告商收取高额费用，实现精准营销。
#
# ### 4. 争议与挑战
# 作为全球最大的科技公司之一，Meta 也面临着巨大的争议和挑战：
# *   **隐私问题：** 多次因用户数据泄露（如剑桥分析事件）和隐私保护不力受到监管机构的调查和巨额罚款。
# *   **内容审核：** 平台上的虚假信息、仇恨言论、网络霸凌以及对青少年心理健康的影响，一直是公众和政府批评的焦点。
# *   **反垄断：** 由于其在社交媒体领域的统治地位，Meta 经常面临反垄断诉讼，被指控通过收购竞争对手（如 Instagram 和 WhatsApp）来扼杀市场竞争。
#
# ### 总结
# 简单来说，**Meta (Facebook) 是一家以社交网络起家，目前通过广告业务盈利，并正全力向人工智能（AI）和元宇宙（VR/AR）领域转型的全球顶级科技公司。**
#
# 它是当今互联网世界中最具影响力的公司之一，深刻地改变了人类沟通、获取信息和进行商业活动的方式。

# %% [markdown]
# ## 使用init_chat_model调用groq大模型
# ### 需要安装langchain-groq
# pip install langchain-groq

# %%
from langchain.chat_models import init_chat_model

# 初始化 Groq 模型
model = init_chat_model("openai/gpt-oss-120b", model_provider="groq")

# 调用模型
response = model.invoke("你好，请介绍一下你自己。")
print(response.content)
# Out:
# 你好！我是ChatGPT，一个由 OpenAI 开发的大型语言模型。以下是我的一些基本信息：
#
# **1. 我的本质**
# - 基于 GPT‑4 架构，我在海量的文本数据上进行训练，能够理解并生成自然语言。
# - 我的知识库覆盖到 2024 年 6 月，包含科学、技术、文化、历史、艺术、日常生活等各个领域的常识。
#
# **2. 能做什么**
# - **对话交流**：可以进行日常聊天、情感陪伴、语言练习等。
# - **信息检索与总结**：帮助查找资料、归纳要点、写作提纲、生成报告。
# - **创意写作**：撰写小说、诗歌、剧本、广告文案、营销方案等。
# - **学习辅导**：解释概念、解答作业题、提供学习资源和学习方法。
# - **编程帮助**：解释代码、调试错误、生成示例代码、讲解算法原理。
# - **多语言支持**：中文、英文、日文、韩文、法文等多种语言的阅读、写作和翻译。
#
# **3. 我的工作方式**
# - **理解上下文**：我会根据对话的前后信息来判断你的意图，尽量提供连贯、相关的回复。
# - **保持中立**：在涉及争议、政治、宗教等敏感话题时，我会遵守安全指南，提供客观、平衡的信息。
# - **尊重隐私**：我不会主动收集或存储个人身份信息，也不会泄露对话内容。
#
# **4. 使用建议**
# - **明确提问**：越具体的问题，我的回答通常越精准。
# - **分步交流**：如果任务较复杂，可以拆分成多个小步骤，我会逐步帮助你完成。
# - **反馈调整**：如果我的回答不符合预期，告诉我哪里需要改进，我可以重新生成或调整方向。
#
# **5. 我的局限**
# - 我的知识截至 2024 年 6 月，之后的最新事件、技术或研究我可能不了解。
# - 虽然我会努力提供准确的信息，但在专业领域（如医学、法律）仍建议咨询相应的专业人士。
# - 我没有感官或真实的情感，只是通过语言模型模拟对话。
#
# 如果你有任何想了解的内容或需要帮助的地方，随时告诉我！祝我们合作愉快。

# %%
from langchain.chat_models import init_chat_model
from dotenv import load_dotenv
import os

from openai import api_key

load_dotenv(override=True)
gemini_api_key=os.getenv("gemini_api_key")

# model = init_chat_model("openai:gpt-4o", temperature=0)
model = init_chat_model(
    model="gemini-3.1-flash-lite",
    model_provider="google_genai",
    api_key=gemini_api_key, temperature=0
    )

# Invoke the model with a simple message
response = model.invoke("Google是一家什么公司")
print(response.text)
# Out:
# Google（谷歌）是一家总部位于美国的**跨国科技巨头**，被公认为全球互联网领域最具影响力的公司之一。
#
# 要全面了解Google，可以从以下几个维度来看：
#
# ### 1. 核心业务：搜索引擎与广告
# *   **搜索引擎（Google Search）：** 这是Google的起家业务，也是目前全球市场份额最高的搜索引擎。它通过复杂的算法，帮助用户在海量信息中快速找到所需内容。
# *   **数字广告（Google Ads）：** 这是Google最主要的收入来源。通过搜索结果、YouTube视频、以及遍布全球网站的广告联盟（AdSense），Google构建了一个庞大的广告生态系统。
#
# ### 2. 核心产品与生态系统
# Google的产品几乎覆盖了现代互联网生活的方方面面：
# *   **操作系统：** **Android**（全球市场份额最大的移动操作系统）。
# *   **浏览器：** **Chrome**（全球使用率最高的网页浏览器）。
# *   **视频平台：** **YouTube**（全球最大的视频分享网站）。
# *   **办公与生产力：** **Google Workspace**（包括Gmail、Google Drive、Google Docs、Google Calendar等）。
# *   **地图与导航：** **Google Maps**（全球最精准的地图服务之一）。
# *   **硬件产品：** **Pixel**系列手机、智能家居设备（Nest）、可穿戴设备（Fitbit）等。
#
# ### 3. 技术研发与前沿领域
# Google以强大的技术研发能力著称，尤其在以下领域处于世界领先地位：
# *   **人工智能（AI）：** Google是全球AI研究的领军者。它开发了Transformer架构（现代大模型的基础），推出了**Gemini**（其最先进的AI模型），并将其深度集成到搜索和办公产品中。
# *   **云计算（Google Cloud）：** 为企业提供云存储、计算能力和数据分析服务，是全球三大云服务商之一。
# *   **自动驾驶：** 其旗下的**Waymo**公司是全球自动驾驶技术的先行者。
#
# ### 4. 公司架构：Alphabet
# 2015年，Google进行了重组，成立了一家名为**Alphabet**的母公司。
# *   **Google**作为Alphabet旗下最大的子公司，负责搜索、广告、地图、YouTube、Android等核心业务。
# *   **“其他赌注”（Other Bets）：** Alphabet还拥有一些探索前沿科技的独立子公司，例如生命科学公司Verily、无人机配送公司Wing等。
#
# ### 5. 企业文化与影响力
# *   **使命：** Google的官方使命是“整合全球信息，供大众使用，使人人受益”（To organize the world's information and make it universally accessible and useful）。
# *   **影响力：** Google不仅改变了人们获取信息的方式，还通过开源项目（如Android、TensorFlow、Kubernetes）深刻影响了整个软件开发行业。
#
# ### 总结
# 简单来说，**Google是一家以“数据”和“算法”为核心的科技公司**。它通过免费提供高质量的互联网服务（如搜索、邮箱、地图）来吸引海量用户，并通过精准的广告投放将这些流量转化为巨大的商业价值，同时利用这些利润不断投入到AI、云计算和未来科技的研发中。
#
# 如果你在日常生活中使用智能手机、上网搜索、看视频或处理文档，几乎很难避开Google提供的服务。

# %%
from langchain.chat_models import init_chat_model
from dotenv import load_dotenv
import os

from openai import api_key

load_dotenv(override=True)
gemini_api_key=os.getenv("gemini_api_key")

# model = init_chat_model("openai:gpt-4o", temperature=0)
model = init_chat_model(
    model="gemini-3.1-flash-lite",
    model_provider="google_genai",
    api_key=gemini_api_key, temperature=0
    )

# Invoke the model with a simple message
response = model.invoke("Google是一家什么公司")
print(response.text)
