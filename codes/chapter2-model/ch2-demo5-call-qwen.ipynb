# %%
from langchain_community.chat_models import ChatTongyi
from dotenv import load_dotenv
import os

load_dotenv(override=True)
DASHSCOPE_API_KEY = os.getenv("DASHSCOPE_API_KEY")

llm = ChatTongyi(
    api_key=DASHSCOPE_API_KEY,
    model="qwen3-max"
    
)

resp = llm.invoke("请分析一下女人的恋爱心理")
print(resp.text)
# Out:
# 分析“女人的恋爱心理”这一话题需要特别谨慎，因为个体差异远大于性别差异。现代心理学强调，人的恋爱心理受性格、成长经历、文化背景、价值观、依恋类型等多重因素影响，而非性别单一决定。不过，基于社会文化和进化心理学的部分研究，可以总结一些**常见但非绝对**的倾向性特征（需注意避免刻板印象）：
#
# ---
#
# ### 一、核心需求：情感联结与安全感
# 1. **情感深度优先**
#    许多女性更重视关系中的情感共鸣、沟通质量与精神契合度，而非单纯物质或外在条件（但并非所有女性如此）。她们倾向于通过语言交流、共情互动建立亲密感。
# 2. **安全感驱动行为**
#    安全感常体现在对伴侣可靠性的关注（如责任感、情绪稳定性），这可能源于社会角色期待或进化中对养育环境稳定性的需求。缺乏安全感时，可能出现试探、回避或过度付出等行为。
#
# ---
#
# ### 二、依恋模式的影响（超越性别）
# 心理学中的**依恋理论**更能解释个体差异：
# - **安全型**：信任伴侣，能平衡亲密与独立。
# - **焦虑型**：渴望亲密但易担忧被抛弃，可能频繁寻求 reassurance（确认爱意）。
# - **回避型**：恐惧亲密，倾向疏离（男女均存在）。
# *注：女性被诊断为焦虑型的比例略高，但回避型同样常见。*
#
# ---
#
# ### 三、社会文化塑造的表达方式
# 1. **间接表达倾向**
#    受传统性别角色影响，部分女性可能更习惯用暗示、情绪信号传递需求（如生气代替直接说“我需要陪伴”），但这正在随平权意识提升而改变。
# 2. **关系中的自我价值感**
#    社会常将女性价值与“被爱”绑定，可能导致部分人通过恋爱确认自我价值，需警惕过度依赖。
#
# ---
#
# ### 四、重要提醒：避免刻板印象陷阱
# 1. **个体差异 > 性别差异**
#    一个理性冷静的女性与一个感性细腻的男性完全可能存在，性格特质与性别无必然联系。
# 2. **时代变化显著**
#    现代女性经济独立、教育水平提升，对平等、尊重、共同成长的需求日益凸显，“依附型恋爱”已非主流。
# 3. **警惕“本质主义”谬误**
#    将心理特征归因于生理性别，容易忽视社会建构的影响（如“女孩该温柔”的规训）。
#
# ---
#
# ### 五、健康恋爱的关键共识（不分性别）
# - **有效沟通**：直接表达需求比猜测更高效。
# - **边界感**：亲密≠失去自我，互相尊重独立空间。
# - **共同成长**：关系是动态协作，而非单方面索取或牺牲。
#
# ---
#
# ### 总结
# 与其聚焦“女人如何想”，不如关注**具体的人如何感受**。真正理解伴侣，需要放下预设，通过真诚对话观察其独特的情感逻辑。心理学研究的意义在于提供视角，而非定义标签——**每个认真去爱的人，都值得被当作独立的个体对待。**
#
# > 🌟 建议：若想深入理解某位特定女性的心理，最好的方式永远是：**倾听她本人的故事，而非套用理论模板。**
