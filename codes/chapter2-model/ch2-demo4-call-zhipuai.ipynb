# %% [markdown]
# ## pip install langchain-community安装langchain的社区包
# ## 获取智普GLM-5.3-Flash大模型的api key并且保存到.env中，同时需要保存base url
# ## 官网：https://bigmodel.cn/

# %%
from langchain_community.chat_models import ChatZhipuAI
from dotenv import load_dotenv
import os

load_dotenv(override=True)
zhipuai_api_key = os.getenv("ZHIPUAI_API_KEY")
zhipuai_base_url = os.getenv("ZHIPUAI_BASE_URL")

llm=ChatZhipuAI(
    api_key=zhipuai_api_key,
    api_base=zhipuai_base_url,
    model="glm-5.3-flash"
)

# 调用模型
resp= llm.invoke("阿里巴巴是一家什么样的公司")
print(resp.text)
# Out:
# c:\Users\kenny\anaconda3\envs\langchain1.2\Lib\site-packages\jwt\api_jwt.py:147: InsecureKeyLengthWarning: The HMAC key is 16 bytes long, which is below the minimum recommended length of 32 bytes for SHA256. See RFC 7518 Section 3.2.
#   return self._jws.encode(
# # 阿里巴巴集团简介
#
# 阿里巴巴是中国领先的互联网科技公司，1999年由马云和其他17位联合创始人创立于浙江杭州。公司的使命是“让天下没有难做的生意”。
#
# ## 主要业务板块
#
# **电子商务（核心业务）**
# - 淘宝——中国最大的C2C购物平台
# - 天猫——品牌商品的B2C平台
# - 1688、阿里巴巴国际站——B2B批发贸易平台
#
# **云计算**
# - 阿里云是亚太地区领先的云服务提供商，近年来也大力发展人工智能（如通义千问大模型）
#
# **物流**
# - 菜鸟网络——智能物流平台
#
# **本地生活服务**
# - 饿了么（外卖）、高德地图（出行导航）等
#
# **国际业务**
# - 速卖通、Lazada（东南亚电商平台）
#
# **数字娱乐**
# - 优酷视频等
#
# **金融科技（关联公司）**
# - 蚂蚁集团旗下的支付宝是中国主要的移动支付工具
#
# ## 公司特点
#
# - **上市情况**：2014年在纽约证券交易所上市，创下当时全球最大规模IPO纪录；2019年在香港二次上市
# - **标志性活动**：每年11月11日的“双十一”购物节由阿里巴巴开创，已成为全球最大的购物狂欢节
# - **创始人**：马云是中国最具知名度的企业家之一，2019年卸任董事局主席
#
# 如今，阿里巴巴业务已覆盖零售、科技、物流、金融等多个领域，是影响中国乃至全球数字经济格局的重要企业。
#
# 你想深入了解哪个方面？比如它的商业模式、发展历史或某个具体业务？

# %%
from langchain_community.chat_models import ChatZhipuAI

llm=ChatZhipuAI(
    model="glm-5.3-flash"
)

# 调用模型
resp= llm.invoke("阿里巴巴是一家什么样的公司")
print(resp.text)
# Out:
# c:\Users\kenny\anaconda3\envs\langchain1.2\Lib\site-packages\jwt\api_jwt.py:147: InsecureKeyLengthWarning: The HMAC key is 16 bytes long, which is below the minimum recommended length of 32 bytes for SHA256. See RFC 7518 Section 3.2.
#   return self._jws.encode(
# 阿里巴巴集团是中国最大的科技公司之一，1999年由马云和其他17位合伙人共同创立，总部位于浙江杭州。公司的使命是“让天下没有难做的生意”。
#
# ## 主要业务板块
#
# **电子商务(核心业务)**
# - 淘宝：中国最大的C2C购物平台
# - 天猫：面向品牌商家的B2C平台
# - 1688:国内批发采购平台
# - 速卖通:面向海外市场的跨境电商
# - Lazada:东南亚电商平台
#
# **云计算与数字技术**
# - 阿里云：亚太地区领先的云计算服务商
#
# **其他业务**
# - 菜鸟：智慧物流网络
# - 饿了么：本地生活服务平台
# - 优酷：视频平台
# - 钉钉：企业协作办公软件
# - 蚂蚁集团(关联公司)：旗下支付宝是中国主要的移动支付工具
#
# ## 重要事件与特点
#
# - **2014年在纽约证券交易所上市**，创下当时全球最大IPO纪录，2019年又在香港二次上市
# - **创造了“双十一”购物节**，如今已成为全球最大的购物狂欢节
# - 与腾讯、百度并称中国互联网早期的"BAT"三巨头
# - **2023年进行重大组织改革**，拆分为多个业务集团，蔡崇信出任董事会主席，吴泳铭担任CEO
# - 近年来大力发展人工智能，推出了通义千问大模型
#
# 目前阿里巴巴正面临拼多多、抖音电商等新兴对手的激烈竞争，公司战略重心也在向电商和云计算等核心业务收缩聚焦。
#
# 你想了解阿里巴巴的哪个方面更详细的信息吗？
